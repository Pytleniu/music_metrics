# %%
# %load_ext autoreload
# %autoreload 2

# %%
from music_metrics import pitch_metrics
from music_metrics import rythm_metrics
from music_metrics import harmonic_metrics
import pretty_midi
import pypianoroll
import os
from pathlib import Path

# %%
script_dir = Path(os.getcwd())

MIDI_FILE_PATH = script_dir / '..' / 'datasets' / 'test_data.mid'
PR_FILE_PATH = script_dir / '..' / 'datasets' / 'test_data.npz'

# Convert Paths to strings if needed
MIDI_FILE_PATH = str(MIDI_FILE_PATH.resolve())
PR_FILE_PATH = str(PR_FILE_PATH.resolve())

midi_data = pretty_midi.PrettyMIDI(midi_file=MIDI_FILE_PATH)
pr = pypianoroll.from_pretty_midi(midi_data)
# Out:
# c:\Users\Wiktor\Desktop\ZPRP\orignal\zprp-projekt-zespol-16\test2\Lib\site-packages\pretty_midi\pretty_midi.py:100: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(

# %%
# path test
pitch_metrics_path, metrics_pitch_table_path = pitch_metrics.get_pitch_metrics(MIDI_FILE_PATH)
rythm_metrics_path, metrics_rythm_table_path = rythm_metrics.get_rythm_metrics(MIDI_FILE_PATH)
harmonic_metrics_path, metrics_harmonic_table_path = harmonic_metrics.get_harmonic_metrics(MIDI_FILE_PATH)

# midi test
pitch_metris_midi, metrics_pitch_table_midi = pitch_metrics.get_pitch_metrics(midi_data)
rythm_metrics_midi, metrics_rythm_table_midi = rythm_metrics.get_rythm_metrics(midi_data)
harmonic_metrics_midi, metrics_harmonic_table_midi = harmonic_metrics.get_harmonic_metrics(midi_data)

# pianoroll test
pitch_mertics_pianoroll, metrics_pitch_table_pianoroll = pitch_metrics.get_pitch_metrics(pr)
rythm_metrics_pianoroll, metrics_rythm_table_pianoroll = rythm_metrics.get_rythm_metrics(pr)
harmonic_metrics_pianoroll, metrics_harmonic_table_pianoroll = harmonic_metrics.get_harmonic_metrics(pr)
# Out:
# c:\Users\Wiktor\Desktop\ZPRP\orignal\zprp-projekt-zespol-16\test2\Lib\site-packages\pretty_midi\pretty_midi.py:100: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(
# c:\Users\Wiktor\Desktop\ZPRP\orignal\zprp-projekt-zespol-16\test2\Lib\site-packages\pretty_midi\pretty_midi.py:100: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   warnings.warn(

# %%
metrics_pitch_table_path
# Out:
# +-----------------------+---------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |         Metric        |                                Value                                |                                                                                                             Description                                                                                                             |
# +-----------------------+---------------------------------------------------------------------+-------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# ...

# %%
histogram = pitch_metrics_path['pitch_class_histogram']
pitch_metrics.plot_pitch_class_histogram(histogram)

# %%
chroma = pitch_metrics_path['chroma']
pitch_metrics.plot_chromagram(chroma)
